# %%
import pandas as pd
datasets=['Scotia_Business_Inc._Export_Development_and_Investment_Attraction_Activity.csv','Index_for_Regional__Innovation-Driven_Entrepreneurship___IDE_.csv'
          ,'Applicants_and_Recipients_of_Small_Business_Impact_Grant_and_Small_Business_Reopening_and_Support_Grant','Municipal_Fiscal_Statistics_-_Financial_Condition_Indicators.csv']
for d in datasets:    
    # Load data into a pandas dataframe
    data = pd.read_csv('./datasets/'+d)

    # Get column names and data types
    column_names = data.columns.tolist()
    data_types = data.dtypes.tolist()

    # Print column names and data types
    print("\nColumn Names:")
    print(column_names)
    print("\nData Types:")
    print(data_types)
    print("\nNumber of rows:", data.shape[0])
    print("\nData:", data.head())
# Out:
# Column Names:
# ['Account Name', 'nsbi_sector', 'Deal Type', 'NSBI Financial Contribution (Commitment/Announced)', 'Place Name', 'nsbi_county', 'PostalCode', 'fiscal year', 'Longitude', 'Latitude', 'New Georeferenced Column']
#
# Data Types:
# [dtype('O'), dtype('O'), dtype('O'), dtype('int64'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('float64'), dtype('float64'), dtype('O')]
#
# Number of rows: 2542
#
# Data:                        Account Name                   nsbi_sector  \
# 0    Northern Business Intelligence  ICT (includes Digital Media)
# 1  Fourth State Energy Incorporated                        Energy
# 2                       Skinfix Inc        Advanced Manufacturing
# 3                      Singolar Inc  ICT (includes Digital Media)
# 4                  Truro Herbal Co.                 Life Sciences
#
#                       Deal Type  \
# 0  Business Development Program
# 1  Business Development Program
# 2  Business Development Program
# ...
