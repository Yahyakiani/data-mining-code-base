# %%
#what lat got most investment
# in which direction of long and lat does investment increase or decrease
# which of year gets more invest

# To check for dependence among variables, you can use statistical tests such as correlation, covariance, and mutual information.

#     Correlation: Correlation measures the strength of the linear relationship between two variables. 
# You can use the corr() method in pandas to calculate the correlation matrix between variables.

# python

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./datasets/Scotia_Business_Inc._Export_Development_and_Investment_Attraction_Activity.csv')
corr_matrix = df.corr()
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f')
plt.show()
plt.text()
# The resulting correlation matrix will show the pairwise correlation coefficients between variables.

#     Covariance: Covariance measures the joint variability between two variables.
#  You can use the cov() method in pandas to calculate the covariance matrix between variables.

# python
# Out:
# C:\Users\yahya\AppData\Local\Temp\ipykernel_17320\3450938017.py:13: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 16
#      14 sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f')
#      15 plt.show()
# ---> 16 plt.text()
#      17 # The resulting correlation matrix will show the pairwise correlation coefficients between variables.
#      18
#      19 #     Covariance: Covariance measures the joint variability between two variables.
#      20 #  You can use the cov() method in pandas to calculate the covariance matrix between variables.
#      21
#      22 # python
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./datasets/Scotia_Business_Inc._Export_Development_and_Investment_Attraction_Activity.csv')
cov_matrix = df.cov()
sns.heatmap(cov_matrix, cmap='coolwarm')
plt.show()



# The resulting covariance matrix will show the pairwise covariance values between variables.

#     Mutual Information: Mutual information measures the amount of information 
# that one variable provides about another variable. You can use the mutual_info_score() function 
# in scikit-learn to calculate the mutual information between variables.

# bash
# Out:
# C:\Users\yahya\AppData\Local\Temp\ipykernel_6616\2033919364.py:6: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cov_matrix = df.cov()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#read data set as DataFrame
df = pd.read_csv('./datasets/Scotia_Business_Inc._Export_Development_and_Investment_Attraction_Activity.csv')
#group by place name and sum contributions
df_sum = df.groupby("Place Name")["NSBI Financial Contribution (Commitment/Announced)"].sum()
df_sum = df_sum.sort_values(ascending=False)[:20]
#plot bar chart of contributions by place name
plt.bar(df_sum.index, df_sum.values)

plt.xlabel("Place Name")
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.ylabel("NSBI Financial Contribution")
plt.title("Contributions by Place Name")
plt.show()
